# %% [markdown]
# <a href="https://colab.research.google.com/github/theAnujkumar/python-question/blob/main/simpleInterest1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Q5 simple interest
def simpleInterest(p,r,t):
  ans = (p*r*t)/100
  print("ans is : ",ans)

principle = int(input("Enter principle amount: "))
rate = int(input("Enter rate : "))
time = int(input("Enter time: "))
simpleInterest(principle,rate,time)
# Out:
# enter the price100
# enter the discount10
# discount amount :  10.0
# total bill :  90.0
